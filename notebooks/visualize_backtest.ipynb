# %%
# %run backtest.py
# Out:
# Sharpe Ratio: OrderedDict([('sharperatio', -10.813128159538547)])
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-05-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-06-28</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>2</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-23.015%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-5.94%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>22.652%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.04</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-1.30</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.13</td>
#     </tr>
#     <tr>
# ...
